# %%
# !pip install -qq transformers datasets accelerate evaluate -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.5 MB/s eta 0:00:00

# %%
from datasets import load_dataset

gtzan = load_dataset("marsyas/gtzan", "all")
gtzan
# Out:
# Downloading builder script:   0%|          | 0.00/3.38k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/4.42k [00:00<?, ?B/s]
# Downloading and preparing dataset gtzan/all to /root/.cache/huggingface/datasets/marsyas___gtzan/all/0.0.0/8bd0e23c2d9b2be30d36bc6834319772dff22a3bd28527996612386cef003910...
# Downloading data:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset gtzan downloaded and prepared to /root/.cache/huggingface/datasets/marsyas___gtzan/all/0.0.0/8bd0e23c2d9b2be30d36bc6834319772dff22a3bd28527996612386cef003910. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 999
#     })
# })

# %%
gtzan = gtzan["train"].train_test_split(seed=42, shuffle=True, test_size=0.1)
gtzan
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 100
#     })
# })

# %%
from transformers import AutoFeatureExtractor

model_id = "ntu-spml/distilhubert"
feature_extractor = AutoFeatureExtractor.from_pretrained(
    model_id, do_normalize=True, return_attention_mask=True
)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]

# %%
max_duration = 30.0

def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
        return_attention_mask=True,
    )
    return inputs

# %%
gtzan_encoded = gtzan.map(
    preprocess_function, remove_columns=["audio", "file"], batched=True, batch_size=200
)
gtzan_encoded
# Out:
# Map:   0%|          | 0/899 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
gtzan_encoded = gtzan_encoded.rename_column("genre", "label")
gtzan_encoded
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
id2label_fn = gtzan["train"].features["genre"].int2str
id2label = {
    str(i): id2label_fn(i)
    for i in range(len(gtzan_encoded["train"].features["label"].names))
}
label2id = {v: k for k, v in id2label.items()}

# %%
from transformers import AutoModelForAudioClassification

num_labels = len(id2label)

model = AutoModelForAudioClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.30k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/94.0M [00:00<?, ?B/s]
# Some weights of HubertForSequenceClassification were not initialized from the model checkpoint at ntu-spml/distilhubert and are newly initialized: ['classifier.weight', 'projector.weight', 'projector.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import TrainingArguments

model_name = model_id.split("/")[-1]
batch_size = 8
gradient_accumulation_steps = 1
num_train_epochs = 15

training_args = TrainingArguments(
    f"{model_name}-finetuned-gtzan",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    gradient_accumulation_steps=gradient_accumulation_steps,
    auto_find_batch_size=True,
    num_train_epochs=num_train_epochs,
    warmup_ratio=0.1,
    logging_steps=5,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    fp16=True,
    seed=42,
    push_to_hub=True
)

# %%
import evaluate
import numpy as np
metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
from transformers import Trainer

trainer = Trainer(
    model,
    training_args,
    train_dataset=gtzan_encoded["train"],
    eval_dataset=gtzan_encoded["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# Cloning https://huggingface.co/adbcode/distilhubert-finetuned-gtzan into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/adbcode/distilhubert-finetuned-gtzan into local empty directory.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='1695' max='1695' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1695/1695 2:40:02, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.223700</td>
#       <td>2.132578</td>
#       <td>0.390000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.682600</td>
#       <td>1.619902</td>
#       <td>0.550000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.337000</td>
#       <td>1.240200</td>
#       <td>0.680000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.166600</td>
#       <td>1.054133</td>
#       <td>0.740000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.922800</td>
#       <td>0.891952</td>
#       <td>0.790000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.697800</td>
#       <td>0.783569</td>
#       <td>0.800000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.730100</td>
#       <td>0.626542</td>
#       <td>0.840000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.382800</td>
#       <td>0.577296</td>
#       <td>0.830000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.455600</td>
#       <td>0.513257</td>
#       <td>0.840000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.293000</td>
#       <td>0.486913</td>
#       <td>0.870000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.157200</td>
#       <td>0.466347</td>
#       <td>0.860000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.120100</td>
#       <td>0.513571</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.101200</td>
#       <td>0.445647</td>
#       <td>0.860000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.095800</td>
#       <td>0.437627</td>
#       <td>0.870000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.080900</td>
#       <td>0.433993</td>
#       <td>0.860000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1695, training_loss=0.7178650872018133, metrics={'train_runtime': 9618.3032, 'train_samples_per_second': 1.402, 'train_steps_per_second': 0.176, 'total_flos': 9.200982411936e+17, 'train_loss': 0.7178650872018133, 'epoch': 15.0})

# %%
kwargs = {
    "dataset_tags": "marsyas/gtzan",
    "dataset": "GTZAN",
    "model_name": f"{model_name}-finetuned-gtzan",
    "finetuned_from": model_id,
    "tasks": "audio-classification",
}

trainer.push_to_hub(**kwargs)
# Out:
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file runs/Jul22_18-34-38_8d5eb22a2ef3/events.out.tfevents.1690050891.8d5eb22a2ef3.515.0:   0%|         …
# To https://huggingface.co/adbcode/distilhubert-finetuned-gtzan
#    eb4f421..5542781  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/adbcode/distilhubert-finetuned-gtzan
#    eb4f421..5542781  main -> main
#
# To https://huggingface.co/adbcode/distilhubert-finetuned-gtzan
#    5542781..b73ae6f  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/adbcode/distilhubert-finetuned-gtzan
#    5542781..b73ae6f  main -> main
# 'https://huggingface.co/adbcode/distilhubert-finetuned-gtzan/commit/5542781777281c1b19ea827d3825b02e11fd59b5'
